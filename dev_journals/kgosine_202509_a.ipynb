# %% [markdown]
# <a href="https://colab.research.google.com/github/snr-laboratory/snrlab-ic-q-pix-v1/blob/main/dev_journals/kgosine_202509_a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Folded Cascode OpAmp

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1xZS5NLTxOCocRi6MVQCATE9nPbRbZgC_"  height="300" >

# %% [markdown]
# ### DC Sweep
#
# <img src="https://drive.google.com/uc?id=1Go-61qCrMyR6U88RjaXcsLcpyo0d567T"  height="300" >
# <img src="https://drive.google.com/uc?id=1foYKCQR2hz7oi6Y6Mt_PL75l-ilAJRFr"  height="300" >

# %% [markdown]
# ### AC Analysis
# <img src="https://drive.google.com/uc?id=1TCugJFOHvf_gz3w6NRpLUx3cF9z-9nI7"  height="300" >
# <img src="https://drive.google.com/uc?id=18YeRNsZpgUightFnP_a2W5k7BVyH3YG6"  height="300" >

# %% [markdown]
# ### Stability Analysis
# <img src="https://drive.google.com/uc?id=1V82nsQ35qtYUEXzCpapFyc79g4RjmV6Z"  height="300" >
# <img src="https://drive.google.com/uc?id=1W0rAP4gslcMBkDaw_dXwAZo3n5vfjhsJ"  height="300" >

# %% [markdown]
# ### Integration
# <img src="https://drive.google.com/uc?id=1e3bPsWj_GscDBRz33H7IiUOHYeApzBZB"  height="300" >
# <img src="https://drive.google.com/uc?id=1oZLoNWCiA8_i0695nyhezgrF0_TvcK-I"  height="300" >

# %% [markdown]
# ## Dynamic Comparator

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1wb_IMZsRtQXiQGMXO9Uted-UHdysLt_2"  height="300" >

# %% [markdown]
# ### Input Offset Voltage
# To turn on: $665\mu W \leq \Delta V $
# To turn off: $120\mu W \leq \Delta V $

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1QUXzUj0XXeEOMD9Z-mL5hu3FMjhW258F"  height="300" >

# %% [markdown]
# ## QPix Loop

# %% [markdown]
# <img src="https://drive.google.com/uc?id=1Rs2kIPlwwKTOUvtpYTfefTGu0C7pCEve"  height="300" >
# <img src="https://drive.google.com/uc?id=1Q6lcmScob9oc_tHSgYNigjzFaMHyasRM"  height="300" >
# <img src="https://drive.google.com/uc?id=1CAx12NXE73rn_MyMbjc-YNa6i10837BM"  height="300" >
# $\Delta Q=$0.254fC-0.261fC

# %% [markdown]
# ## Power Consumption

# %% [markdown]
# ### During simulated track event:
#
# Average power of integrator = $15.56\mu W$
#
# Average power of comparator = $13.12 \mu W$
#
# Average power of replenishment circuit = $575.6 pW$
#
# ### Integrator Circuit
#
# Average power of integrator = $15.56\mu W$
#
# <img src="https://drive.google.com/uc?id=1vey-g1ObMEAMnGV6NTkWK_ujLddOzyLI"  height="300" >
#
# ### Comparator Circuit
#
# Average power of comparator = $13.97 \mu W$
#
# <img src="https://drive.google.com/uc?id=1nXEBauvRz6Qe3g1dRdweaW77nn3C-1x3"  height="300" >
# <img src="https://drive.google.com/uc?id=1wMZpZNsVhldS3Jdw-5ijQyiTrcEl6yAI"  height="300" >
#
#
# ### Replenishment Circuit
#
# Average power of replenishment circuit = $575.6 pW$
# <img src="https://drive.google.com/uc?id=14P5lXcPYfQY0BO8LV99hclIESWMB_Xhn"  height="300" >
# <img src="https://drive.google.com/uc?id=1U4KpSvklOcTSclyrPqe1oIpQQhCUQHHf"  height="300" >
#
#
# ### Total Loop
#
# Average power = $ 49.07 \mu W$
#
# <img src="https://drive.google.com/uc?id=1VE183vF_r6Mfatsw0BeOIl7DPeDTPnAM"  height="300" >

# %% [markdown]
# ### With no input current (Quiet period)
