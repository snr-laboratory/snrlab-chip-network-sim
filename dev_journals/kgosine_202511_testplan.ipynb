# %% [markdown]
# <a href="https://colab.research.google.com/github/snr-laboratory/snrlab-ic-q-pix-v1/blob/main/dev_journals/kgosine_202511_testplan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### IO Pins
#
# |Pin Name | Description | Current Draw|
# |---|---|---|
# |VDD| Power supply | |
# |VSS|Chip GND| |
# |PIXEL_PAD| Charge collection pixel|5nA|
# |INT_SPY| Integrator output spy point|$\pm$ 2uA|
# |SPY_CURR| Current source for spy point|4uA|
# |REPL_OUTP| Positive LVDS signal of calls for replenishment|$\pm$ 3.5mA|
# |REPL_OUTN| Negative LVDS signal of calls for replenishment|$\pm$ 3.5mA|
# |CLK_INP| Positive LVDS clock signal||
# |CLK_INN| Negative LVDS clock signal||
# |BIAS_CTRL| Bias current for analog biasing circuitry||
# |VREF| Integrator threshold voltage||
# |VREF_COMP| Comparator threshold voltage||
# |AVDD| Replenishment voltage|50nA, 0A avg|
# |RX_CURR| Bias current for LVDS receiver|5uA|
# |CLK_SPY| Receiver output (clock) spy point||
# |CLK_SPY_CURR| Bias current for clock spy point ||

# %% [markdown]
# ### Signs of Life
#
# #### Clock
# See 50MHz LVDS clock signal is recovered by the receiver via CLK_SPY
#
# ### Integrator
# INT_SPY should sit at 900mV with no incoming charge

# %% [markdown]
# ### Concerns
#
# Voltage biasing the pixel pad? With a DAC?
