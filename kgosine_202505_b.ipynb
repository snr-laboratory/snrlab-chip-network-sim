# %% [markdown]
# <a href="https://colab.research.google.com/github/snr-laboratory/snrlab-ic-q-pix-v1/blob/main/kgosine_202505_b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Biased the current source into the differential input using a current mirror (ibias1) rather than a voltage source:
#
#
# <img src="https://drive.google.com/uc?id=19GFD0B3mYHHQE32uJU4gzvkyBsz4iT6R"  width="300" >

# %% [markdown]
# No feedback behavior onthe left looks okay, Vinn=Vdd/2, Vinp dc sweep from 0V to Vdd. When in a non-inverting configuration (voltage buffer) the input and output match upto Vin of about 1.4V:
# <img src="https://drive.google.com/uc?id=1vm4WWhMCSGXVBeHCJQ9q361WEk4CeYUI"  height="400" >
# <img src="https://drive.google.com/uc?id=1dLpGWpixqTyz8i1-vBqt9QD4FtJZ-8qM"  height="400" >

# %% [markdown]
# A stability analysis was done on the circuit in the unit gain cconfiguration. The phase margin is 57.443 deg and the cross over frequency (gain goes from greater than 1 to less than 1) was 844.09 MHz. The loop gain is about 48dB (voltage gain of 251) for frequencies below 1MHz. The gain is reduced by -3dB at 4.78MHz (the bandwidth).
#
# <img src="https://drive.google.com/uc?id=1AlfXK4m1FobKXjeTOBnhZBWxS0c5cddq"  height="400" >

# %% [markdown]
# Doing an AC analysis I get slightly different results:
# Bandwidth=9.3MHz, UnityGainFreq=1.711GHz, PhaseMargin=38deg
#
# <img src="https://drive.google.com/uc?id=1_wo_xb5EVqeiJ3InApnaE-3BAOg-FesC"  height="400" >
